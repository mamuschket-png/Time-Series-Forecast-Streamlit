# %% [markdown]
# # Import data
#
# store nbr = 44
# item nbr = 1047679

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
holidays = pd.read_csv("data/holidays.csv")

# %%
holidays
# Out:
#            date    locale locale_name                    description
# 0    2012-03-02     Local       Manta             Fundacion de Manta
# 1    2012-04-01  Regional    Cotopaxi  Provincializacion de Cotopaxi
# 2    2012-04-12     Local      Cuenca            Fundacion de Cuenca
# 3    2012-04-14     Local    Libertad      Cantonizacion de Libertad
# 4    2012-04-21     Local    Riobamba      Cantonizacion de Riobamba
# ..          ...       ...         ...                            ...
# 345  2017-12-22  National     Ecuador                      Navidad-3
# 346  2017-12-23  National     Ecuador                      Navidad-2
# 347  2017-12-24  National     Ecuador                      Navidad-1
# 348  2017-12-25  National     Ecuador                        Navidad
# 349  2017-12-26  National     Ecuador                      Navidad+1
#
# [350 rows x 4 columns]

# %%
stores = pd.read_csv("data/stores.csv")
stores
# Out:
#     store_nbr           city                          region
# 0           1          Quito                       Pichincha
# 1           2          Quito                       Pichincha
# 2           3          Quito                       Pichincha
# 3           4          Quito                       Pichincha
# 4           5  Santo Domingo  Santo Domingo de los Tsachilas
# 5           6          Quito                       Pichincha
# 6           7          Quito                       Pichincha
# 7           8          Quito                       Pichincha
# 8           9          Quito                       Pichincha
# 9          10          Quito                       Pichincha
# 10         11        Cayambe                       Pichincha
# 11         12      Latacunga                        Cotopaxi
# 12         13      Latacunga                        Cotopaxi
# 13         14       Riobamba                      Chimborazo
# 14         15         Ibarra                        Imbabura
# 15         16  Santo Domingo  Santo Domingo de los Tsachilas
# 16         17          Quito                       Pichincha
# 17         18          Quito                       Pichincha
# 18         19       Guaranda                         Bolivar
# 19         20          Quito                       Pichincha
# 20         21  Santo Domingo  Santo Domingo de los Tsachilas
# 21         22           Puyo                         Pastaza
# 22         23         Ambato                      Tungurahua
# 23         24      Guayaquil                          Guayas
# 24         25        Salinas                     Santa Elena
# 25         26      Guayaquil                          Guayas
# 26         27          Daule                          Guayas
# 27         28      Guayaquil                          Guayas
# 28         29      Guayaquil                          Guayas
# 29         30      Guayaquil                          Guayas
# 30         31       Babahoyo                        Los Rios
# 31         32      Guayaquil                          Guayas
# 32         33        Quevedo                        Los Rios
# 33         34      Guayaquil                          Guayas
# 34         35         Playas                          Guayas
# 35         36       Libertad                          Guayas
# 36         37         Cuenca                           Azuay
# 37         38           Loja                            Loja
# 38         39         Cuenca                           Azuay
# 39         40        Machala                          El Oro
# 40         41        Machala                          El Oro
# 41         42         Cuenca                           Azuay
# 42         43     Esmeraldas                      Esmeraldas
# 43         44          Quito                       Pichincha
# 44         45          Quito                       Pichincha
# 45         46          Quito                       Pichincha
# 46         47          Quito                       Pichincha
# 47         48          Quito                       Pichincha
# 48         49          Quito                       Pichincha
# 49         50         Ambato                      Tungurahua
# 50         51      Guayaquil                          Guayas
# 51         52          Manta                          Manabi
# 52         53          Manta                          Manabi
# 53         54      El Carmen                          Manabi

# %%
df = pd.read_csv("data/timeseries.csv")

# %%
df
# Out:
#            date  unit_sales
# 0    2013-01-02       582.0
# 1    2013-01-03       310.0
# 2    2013-01-04       338.0
# 3    2013-01-05       654.0
# 4    2013-01-06       979.0
# ..          ...         ...
# 447  2014-03-27       328.0
# 448  2014-03-28       523.0
# 449  2014-03-29       647.0
# 450  2014-03-30       599.0
# 451  2014-03-31       415.0
#
# [452 rows x 2 columns]

# %%
pd.to_datetime(df['date'])
# Out:
# 0     2013-01-02
# 1     2013-01-03
# 2     2013-01-04
# 3     2013-01-05
# 4     2013-01-06
#          ...
# 447   2014-03-27
# 448   2014-03-28
# 449   2014-03-29
# 450   2014-03-30
# 451   2014-03-31
# Name: date, Length: 452, dtype: datetime64[us]

# %%
df['date'] = pd.to_datetime(df['date'])  # Ensure 'date' column is in datetime format
df.set_index('date', inplace=True)  # Set 'date' as the index

# %%
df
# Out:
#             unit_sales
# date
# 2013-01-02       582.0
# 2013-01-03       310.0
# 2013-01-04       338.0
# 2013-01-05       654.0
# 2013-01-06       979.0
# ...                ...
# 2014-03-27       328.0
# 2014-03-28       523.0
# 2014-03-29       647.0
# 2014-03-30       599.0
# 2014-03-31       415.0
#
# [452 rows x 1 columns]

# %%
# Visualize the data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['unit_sales'], label='Unit Sales')
plt.title('Unit Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Unit Sales')
plt.legend()
plt.show()

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Outlier Detection

# %%
df['unit_sales']
# Out:
# date
# 2013-01-02    582.0
# 2013-01-03    310.0
# 2013-01-04    338.0
# 2013-01-05    654.0
# 2013-01-06    979.0
#               ...
# 2014-03-27    328.0
# 2014-03-28    523.0
# 2014-03-29    647.0
# 2014-03-30    599.0
# 2014-03-31    415.0
# Name: unit_sales, Length: 452, dtype: float64

# %%
# Calculate z-scores to identify outliers
from scipy import stats
import numpy as np
z_scores = np.abs(stats.zscore(df['unit_sales']))
outliers = df[z_scores > 3]
outliers
# Out:
#             unit_sales
# date
# 2013-01-20      1090.0
# 2014-01-05      1203.0
# 2014-01-16      1168.0

# %% [markdown]
# ## Missing Values

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# unit_sales    0
# dtype: int64

# %%
df.index.max()
# Out:
# Timestamp('2014-03-31 00:00:00')

# %%
pd.date_range(start=df.index.min(), end=df.index.max())
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05',
#                '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09',
#                '2013-01-10', '2013-01-11',
#                ...
#                '2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31'],
#               dtype='datetime64[us]', length=454, freq='D')

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-02', '2013-01-03', '2013-01-04', '2013-01-05',
#                '2013-01-06', '2013-01-07', '2013-01-08', '2013-01-09',
#                '2013-01-10', '2013-01-11',
#                ...
#                '2014-03-22', '2014-03-23', '2014-03-24', '2014-03-25',
#                '2014-03-26', '2014-03-27', '2014-03-28', '2014-03-29',
#                '2014-03-30', '2014-03-31'],
#               dtype='datetime64[us]', name='date', length=452, freq=None)

# %%
# Check if all days are present
date_range = pd.date_range(start=df.index.min(), end=df.index.max(), freq="D")
missing_dates = date_range.difference(df.index)
missing_dates
# Out:
# DatetimeIndex(['2013-12-25', '2014-01-01'], dtype='datetime64[us]', freq=None)

# %%
# Solve missing dates by forward filling
df = df.reindex(date_range)
df
# Out:
#             unit_sales
# 2013-01-02       582.0
# 2013-01-03       310.0
# 2013-01-04       338.0
# 2013-01-05       654.0
# 2013-01-06       979.0
# ...                ...
# 2014-03-27       328.0
# 2014-03-28       523.0
# 2014-03-29       647.0
# 2014-03-30       599.0
# 2014-03-31       415.0
#
# [454 rows x 1 columns]

# %%
df[df.isnull()['unit_sales']]
# Out:
#             unit_sales
# 2013-12-25         NaN
# 2014-01-01         NaN

# %%
# Fill missing unit_sales with forward fill
df['unit_sales'] = df['unit_sales'].ffill()

# %%
df.isnull().sum()
# Out:
# unit_sales    0
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
summary_stats = df['unit_sales'].describe()
summary_stats
# Out:
# count     454.000000
# mean      479.740088
# std       170.560195
# min         4.000000
# 25%       358.500000
# 50%       443.500000
# 75%       576.750000
# max      1203.000000
# Name: unit_sales, dtype: float64

# %% [markdown]
# ## Seasonal Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Set frequenc to daily
df = df.asfreq('D')  # This is done for seasonal decomposition to infere seasonal patterns
# Perform seasonal decomposition
decomposition = seasonal_decompose(df['unit_sales'], model='additive')
decomposition.plot()
plt.show()

# %% [markdown]
# ## Stationarity Test

# %%
from statsmodels.tsa.stattools import adfuller
# Perform Augmented Dickey-Fuller test
adf_result = adfuller(df['unit_sales'])
adf_result[1]
# Out:
# np.float64(1.7554305139623423e-05)

# %%
from statsmodels.tsa.stattools import adfuller
# Perform Augmented Dickey-Fuller test
adf_result = adfuller(df['unit_sales'])
adf_result_dict = {
    'ADF Statistic': adf_result[0],
    'p-value': adf_result[1],
    'Critical Values': adf_result[4]
}
adf_result_dict
# Out:
# {'ADF Statistic': np.float64(-5.051243167393035),
#  'p-value': np.float64(1.7554305139623423e-05),
#  'Critical Values': {'1%': np.float64(-3.4454725477848998),
#   '5%': np.float64(-2.8682072297316794),
#   '10%': np.float64(-2.570321396485665)}}

# %% [markdown]
# ## Autocorrelation Analysis

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
# Plot ACF and PACF
plt.figure(figsize=(12, 6))
plt.subplot(121)
plot_acf(df['unit_sales'], ax=plt.gca(), lags=50)
plt.subplot(122)
plot_pacf(df['unit_sales'], ax=plt.gca(), lags=50)
plt.show()

# %% [markdown]
# ## Save cleaned data

# %%
# Save the cleaned data
df.index.name = "date"
df.to_csv("data/cleaned_timeseries.csv", index=True)

# %% [markdown]
# # For Students: Further EDA and Analysis
# Ideas:
#     - Do holidays impact sales?
#     - Does the day of the week the impact sales?
#     - Does the oil price impact sales?
#     - Get creative and explore the data further! Even if the results show that there is no impact, that is still a useful finding!! We would like mostly to see the thought process no need on statistical perfection (:
