# %%
import mlflow

# %%
# Beispiel: Wenn du testen möchtest, wie sich das LSTM-Modell im Vergleich zu XGBoost schlägt, könnte dein Experiment “LSTM_vs_XGB” heißen.

# Experimentname festlegen
mlflow.set_experiment("LSTM_vs_XGB")   # erstellt das Experiment einmalig, nutzt es beim nächsten Mal wieder
