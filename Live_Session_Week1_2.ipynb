# %% [markdown]
# Modelle um Zukunft vorherzusagen:
# (a) statistische Modelle
# > statistische Modelle scheitern bei sehr komplexen Bedingungen, dafür aber super interpretierbar
# > schnell
# > Bsp. ARIMA Modelle
#
# (B) ML-Modelle
